# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
import os
import torch.onnx
import sklearn

# %%
# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")  # Use the default GPU device
else:
    device = torch.device("cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Data Exploration

# %%
dataframes = []
train_data_directory = "../EyeTrackingTest/Data"
for file in os.listdir(train_data_directory):
    dataframes.append(pd.read_csv(os.path.join(train_data_directory, file), delimiter=",").iloc[:,:-1])
    print(f"{len(dataframes)-1}:{file}")
# Out:
# 0:83_0.txt
# 1:83_1.txt
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32288\3800501084.py in <module>
#       2 train_data_directory = "../EyeTrackingTest/Data"
#       3 for file in os.listdir(train_data_directory):
# ----> 4     dataframes.append(pd.read_csv(os.path.join(train_data_directory, file), delimiter=",").iloc[:,:-1])
#       5     print(f"{len(dataframes)-1}:{file}")
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: '../EyeTrackingTest/Data\\data_without3'

# %%
for j in range(len(dataframes)):
    df = dataframes[j]
    labelx = []
    labely = []
    labelz = []
    for i in range(df.shape[0] - 1):
        label_row = df.iloc[i + 1]
        labelx.append(label_row["forward.x"])
        labely.append(label_row["forward.y"])
        labelz.append(label_row["forward.z"])

    df = df.iloc[:-1, :]
    df["label.x"] = labelx
    df["label.y"] = labely
    df["label.z"] = labelz
    dataframes[j] = df
    if(df.shape[0]!=10800):
        print(f"data size Error({j}:{df.shape})")

#dataframes[3].head(5)

# %%
df = dataframes[1]
print(df.shape)
plt.figure(figsize=(10,6))

x = df["time_stamp(ms)"]
    
plt.xlabel("time_stamp(ms)")

plt.plot(x, df["gaze_direct_L.y"], label = "gaze_direct_L.y")
plt.plot(x, df["gaze_direct_R.y"], label = "gaze_direct_R.y")
plt.plot(x, df["forward.y"], label = "forward.y")
#plt.xlim(213000,214000)

plt.title(f"Neck & Eye Gaze Data(axis Y)")
plt.legend()
plt.show()
# Out:
# (10800, 15)

# %%
df = dataframes[0]
print(df.shape)
plt.figure(figsize=(10,6))

x = df["time_stamp(ms)"]
    
plt.xlabel("time_stamp(ms)")

plt.plot(x, df["gaze_direct_L.y"], label = "gaze_direct_L.y")
plt.plot(x, df["gaze_direct_R.y"], label = "gaze_direct_R.y")
plt.plot(x, df["forward.y"], label = "forward.y")
#plt.xlim(213000,214000)

plt.title(f"Neck Prediction Y")
plt.legend()
plt.show()
# Out:
# (10800, 15)

# %%
print(df.shape)
plt.figure(figsize=(10,6))

x = df["time_stamp(ms)"]
    
plt.xlabel("time_stamp(ms)")

plt.plot(x, df["gaze_direct_L.y"], label = "gaze_direct_L.y")
plt.plot(x, df["gaze_direct_R.y"], label = "gaze_direct_R.y")


plt.title(f"Neck Prediction Y")
plt.legend()
plt.show()
# Out:
# (10800, 15)

# %%
#The chat shows the relation of gaze and forward in the raw data.

df = dataframes[1]
print(df.shape)
plt.figure(figsize=(10,6))
x = df["time_stamp(ms)"]


plt.plot(x, df["gaze_direct_L.y"], label = "gaze_direct_L.y")
plt.plot(x, df["forward.y"], label="forward.y")

plt.title("Neck Prediction Y")
plt.legend()
plt.show()
# Out:
# (10800, 15)

# %%
min_size = float('inf')
for df in dataframes:
    if df.shape[0] < min_size:
        min_size = df.shape[0]

for i in range(len(dataframes)):
    dataframes[i] = dataframes[i][:min_size] # ensure that all dataframes i the list have the same number of rows
    df = df[:min_size]

# %% [markdown]
# ## LSTM Model

# %%
X_series = []
y_series = []
for df in dataframes:
    X = df.iloc[:, 3:-3].to_numpy() # gaze data and forward data
    y = df.iloc[:, -3:].to_numpy()  # label data 

    X = Variable(torch.Tensor(X)) # trnsform to Tensor object (2d)
    y = Variable(torch.Tensor(y))
    
    X = torch.reshape(X, (X.shape[0], 1, X.shape[1])) # 3d Tensor object
    X_series.append(X)
    y_series.append(y)


X_series = torch.cat(X_series, dim=1)

y_series = torch.stack(y_series, dim=1)
print(X_series.shape, y_series.shape)
print(X.type)
print(X.shape)
# Out:
# torch.Size([10799, 228, 9]) torch.Size([10799, 228, 3])
# <built-in method type of Tensor object at 0x0000023B0E5C04F0>
# torch.Size([10799, 1, 9])

# %%
class CustomLSTM(nn.Module):
    def __init__(self, input_size, output_size=3, hidden_size=9):
        super(CustomLSTM, self).__init__() ##nn.Module __init__()
        self.num_classes = output_size
        self.num_layers = 1
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.lstm = nn.LSTM(input_size=self.input_size, hidden_size=self.hidden_size, num_layers=self.num_layers, batch_first=True)
        self.fc = nn.Sequential(
            nn.Tanh(),
            nn.Linear(self.hidden_size, 128),
            nn.Tanh(),
            nn.Linear(128, self.num_classes)
        )
    
    def forward(self, x, h_0=None, c_0=None):
        if h_0 is None:
            h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(torch.device("cuda"))
        if c_0 is None:
            c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)).to(torch.device("cuda"))
        
        output, (hn, cn) = self.lstm(x, (h_0, c_0))
        _hn = hn.view(-1, self.hidden_size)
        out = self.fc(_hn)
        return out, hn, cn

# %% [markdown]
# ## Training Loop and Results

# %%
def train(model, X, y, optimizer, criterion, device):
    model.train()
    optimizer.zero_grad()
    preds = torch.zeros(y.shape).to(device)
    loss = 0
    for j in range(X.shape[1]):
        instance = X[0:1, j:j+1, :]
        hn = None
        cn = None
        for i in range(6000):
            pred, hn, cn = model(instance, hn, cn)
            pred = nn.functional.normalize(pred)
            #preds[i, j] = pred
            cur_loss = criterion(pred, y[i:i+1, j])
            loss += criterion(pred, y[i:i+1, j]) / (6000 * X.shape[1])
            #losses.append(cur_loss.item())
            
            if i < 5999:
                l_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,0:3] - pred[0], (1,3)))
                r_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,3:6] - pred[0], (1,3)))
                instance = torch.reshape(torch.cat((l_pred, r_pred, pred), axis=1), (1,1,9))
    #loss = criterion(preds[:6000], y[:6000])
    loss.backward()
    optimizer.step()
    return loss.item()

# %%
def val(model, X, y, criterion, device):
    model.eval()
    preds = torch.zeros(y.shape).to(device)
    for j in range(X.shape[1]):
        instance = X[0:1, j:j+1, :]
        hn = None
        cn = None
        for i in range(X.shape[0]):
            pred, hn, cn = model(instance, hn, cn)
            pred = nn.functional.normalize(pred)
            preds[i, j] = pred
            if i < X.shape[0] - 1:
                l_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,0:3] - pred[0], (1,3)))
                r_pred = nn.functional.normalize(torch.reshape(X[i+1,j:j+1,6:9] + X[i+1,j:j+1,3:6] - pred[0], (1,3)))
                instance = torch.reshape(torch.cat((l_pred, r_pred, pred), axis=1), (1,1,9))
    loss = criterion(preds[6000:], y[6000:])
    return loss.item()

# %%
def train_loop(model, X, y, optimizer, device, scheduler, num_epochs):
    train_losses = []
    val_losses = []
    counter = 0
    X = X.to(device)
    y = y.to(device)
    min_val_loss = val(model, X, y, criterion, device)
    for epoch in range(num_epochs):
        train_loss = train(model, X, y, optimizer, criterion, device)
        train_losses.append(train_loss)
        
        val_loss = val(model, X, y, criterion, device)
        val_losses.append(val_loss)
        
        print("Epoch: %d, train loss: %1.5f, val loss: %1.5f" % (epoch, train_loss, 
                                                                 val_losses[epoch]))
        if val_losses[epoch] < min_val_loss:
            min_val_loss = val_losses[epoch]
            counter = 0
            torch.save(model.state_dict(), "best_val.pth")
        else:
            counter += 1
            if counter > 10:
                break
        
        if epoch+1 % 10 == 0:
            scheduler.step()
        
    return train_losses, val_losses

# %%
learning_rate = 0.001
criterion = torch.nn.MSELoss()

device = torch.device("cuda")

lr_xyz = CustomLSTM(input_size=9).to(device)
optimizer = torch.optim.Adam(lr_xyz.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
train_losses, val_losses = train_loop(lr_xyz, X_series, y_series, optimizer, device, scheduler, 1000)
# Out:
# Epoch: 0, train loss: 1.18580, val loss: 0.72253
# Epoch: 1, train loss: 0.71684, val loss: 0.53934
# Epoch: 2, train loss: 0.53201, val loss: 0.41979
# Epoch: 3, train loss: 0.41244, val loss: 0.33660
# Epoch: 4, train loss: 0.32970, val loss: 0.27777
# Epoch: 5, train loss: 0.27146, val loss: 0.23645
# Epoch: 6, train loss: 0.23079, val loss: 0.20781
# Epoch: 7, train loss: 0.20279, val loss: 0.18819
# Epoch: 8, train loss: 0.18375, val loss: 0.17476
# Epoch: 9, train loss: 0.17081, val loss: 0.16558
# Epoch: 10, train loss: 0.16207, val loss: 0.15922
# Epoch: 11, train loss: 0.15608, val loss: 0.15474
# Epoch: 12, train loss: 0.15193, val loss: 0.15152
# Epoch: 13, train loss: 0.14900, val loss: 0.14910
# Epoch: 14, train loss: 0.14684, val loss: 0.14719
# Epoch: 15, train loss: 0.14515, val loss: 0.14560
# Epoch: 16, train loss: 0.14377, val loss: 0.14418
# Epoch: 17, train loss: 0.14253, val loss: 0.14286
# Epoch: 18, train loss: 0.14137, val loss: 0.14156
# Epoch: 19, train loss: 0.14020, val loss: 0.14026
# Epoch: 20, train loss: 0.13903, val loss: 0.13895
# Epoch: 21, train loss: 0.13783, val loss: 0.13756
# Epoch: 22, train loss: 0.13653, val loss: 0.13615
# Epoch: 23, train loss: 0.13520, val loss: 0.13470
# Epoch: 24, train loss: 0.13382, val loss: 0.13323
# Epoch: 25, train loss: 0.13240, val loss: 0.13174
# Epoch: 26, train loss: 0.13094, val loss: 0.13023
# Epoch: 27, train loss: 0.12946, val loss: 0.12872
# Epoch: 28, train loss: 0.12796, val loss: 0.12720
# Epoch: 29, train loss: 0.12644, val loss: 0.12568
# Epoch: 30, train loss: 0.12492, val loss: 0.12415
# Epoch: 31, train loss: 0.12338, val loss: 0.12265
# Epoch: 32, train loss: 0.12186, val loss: 0.12114
# Epoch: 33, train loss: 0.12034, val loss: 0.11966
# Epoch: 34, train loss: 0.11883, val loss: 0.11816
# Epoch: 35, train loss: 0.11731, val loss: 0.11670
# Epoch: 36, train loss: 0.11584, val loss: 0.11523
# Epoch: 37, train loss: 0.11435, val loss: 0.11377
# Epoch: 38, train loss: 0.11288, val loss: 0.11231
# Epoch: 39, train loss: 0.11140, val loss: 0.11086
# Epoch: 40, train loss: 0.10995, val loss: 0.10942
# Epoch: 41, train loss: 0.10849, val loss: 0.10795
# Epoch: 42, train loss: 0.10703, val loss: 0.10649
# Epoch: 43, train loss: 0.10557, val loss: 0.10501
# Epoch: 44, train loss: 0.10408, val loss: 0.10353
# Epoch: 45, train loss: 0.10262, val loss: 0.10203
# Epoch: 46, train loss: 0.10114, val loss: 0.10051
# Epoch: 47, train loss: 0.09965, val loss: 0.09897
# Epoch: 48, train loss: 0.09814, val loss: 0.09743
# Epoch: 49, train loss: 0.09662, val loss: 0.09587
# Epoch: 50, train loss: 0.09509, val loss: 0.09428
# Epoch: 51, train loss: 0.09354, val loss: 0.09268
# Epoch: 52, train loss: 0.09197, val loss: 0.09107
# Epoch: 53, train loss: 0.09039, val loss: 0.08942
# Epoch: 54, train loss: 0.08877, val loss: 0.08777
# Epoch: 55, train loss: 0.08716, val loss: 0.08609
# Epoch: 56, train loss: 0.08552, val loss: 0.08440
# Epoch: 57, train loss: 0.08386, val loss: 0.08271
# Epoch: 58, train loss: 0.08220, val loss: 0.08100
# Epoch: 59, train loss: 0.08052, val loss: 0.07927
# Epoch: 60, train loss: 0.07883, val loss: 0.07754
# Epoch: 61, train loss: 0.07714, val loss: 0.07579
# Epoch: 62, train loss: 0.07541, val loss: 0.07404
# Epoch: 63, train loss: 0.07369, val loss: 0.07228
# Epoch: 64, train loss: 0.07196, val loss: 0.07052
# Epoch: 65, train loss: 0.07024, val loss: 0.06876
# Epoch: 66, train loss: 0.06851, val loss: 0.06701
# Epoch: 67, train loss: 0.06679, val loss: 0.06526
# Epoch: 68, train loss: 0.06507, val loss: 0.06352
# Epoch: 69, train loss: 0.06336, val loss: 0.06178
# Epoch: 70, train loss: 0.06165, val loss: 0.06007
# Epoch: 71, train loss: 0.05996, val loss: 0.05836
# Epoch: 72, train loss: 0.05828, val loss: 0.05667
# Epoch: 73, train loss: 0.05662, val loss: 0.05501
# Epoch: 74, train loss: 0.05498, val loss: 0.05336
# Epoch: 75, train loss: 0.05335, val loss: 0.05172
# Epoch: 76, train loss: 0.05173, val loss: 0.05012
# Epoch: 77, train loss: 0.05015, val loss: 0.04854
# Epoch: 78, train loss: 0.04860, val loss: 0.04699
# Epoch: 79, train loss: 0.04706, val loss: 0.04546
# Epoch: 80, train loss: 0.04555, val loss: 0.04398
# Epoch: 81, train loss: 0.04408, val loss: 0.04252
# Epoch: 82, train loss: 0.04263, val loss: 0.04110
# Epoch: 83, train loss: 0.04122, val loss: 0.03971
# Epoch: 84, train loss: 0.03984, val loss: 0.03836
# Epoch: 85, train loss: 0.03850, val loss: 0.03705
# Epoch: 86, train loss: 0.03721, val loss: 0.03578
# Epoch: 87, train loss: 0.03594, val loss: 0.03456
# Epoch: 88, train loss: 0.03472, val loss: 0.03338
# Epoch: 89, train loss: 0.03355, val loss: 0.03224
# Epoch: 90, train loss: 0.03242, val loss: 0.03115
# Epoch: 91, train loss: 0.03134, val loss: 0.03011
# Epoch: 92, train loss: 0.03030, val loss: 0.02913
# Epoch: 93, train loss: 0.02931, val loss: 0.02817
# Epoch: 94, train loss: 0.02836, val loss: 0.02728
# Epoch: 95, train loss: 0.02747, val loss: 0.02643
# Epoch: 96, train loss: 0.02662, val loss: 0.02564
# Epoch: 97, train loss: 0.02583, val loss: 0.02490
# Epoch: 98, train loss: 0.02508, val loss: 0.02420
# Epoch: 99, train loss: 0.02438, val loss: 0.02356
# Epoch: 100, train loss: 0.02374, val loss: 0.02297
# Epoch: 101, train loss: 0.02315, val loss: 0.02244
# Epoch: 102, train loss: 0.02260, val loss: 0.02196
# Epoch: 103, train loss: 0.02212, val loss: 0.02154
# Epoch: 104, train loss: 0.02170, val loss: 0.02116
# Epoch: 105, train loss: 0.02133, val loss: 0.02085
# Epoch: 106, train loss: 0.02102, val loss: 0.02058
# Epoch: 107, train loss: 0.02075, val loss: 0.02036
# Epoch: 108, train loss: 0.02052, val loss: 0.02013
# Epoch: 109, train loss: 0.02036, val loss: 0.02002
# Epoch: 110, train loss: 0.02032, val loss: 0.01995
# Epoch: 111, train loss: 0.02033, val loss: 0.01990
# Epoch: 112, train loss: 0.02031, val loss: 0.01986
# Epoch: 113, train loss: 0.02029, val loss: 0.06298
# Epoch: 114, train loss: 0.06646, val loss: 0.19048
# Epoch: 115, train loss: 0.20114, val loss: nan
# Epoch: 116, train loss: nan, val loss: nan
# Epoch: 117, train loss: nan, val loss: nan
# Epoch: 118, train loss: nan, val loss: nan
# Epoch: 119, train loss: nan, val loss: nan
# Epoch: 120, train loss: nan, val loss: nan
# Epoch: 121, train loss: nan, val loss: nan
# Epoch: 122, train loss: nan, val loss: nan
# Epoch: 123, train loss: nan, val loss: nan

# %%
learning_rate = 0.0001
criterion = torch.nn.MSELoss()

device = torch.device("cuda")
lr_xyz = CustomLSTM(input_size=9).to(device)
lr_xyz.load_state_dict(torch.load("best_val.pth"))
optimizer = torch.optim.Adam(lr_xyz.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
torch.onnx.export(lr_xyz.cpu(),               # model being run
                  (X[0:1, 0:1, :], torch.zeros(1, 1, 9), torch.zeros(1, 1, 9)), # model input (or a tuple for multiple inputs)
                  "lr_xyz.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input', 'h0', 'c0'],   # the model's input names
                  output_names = ['output', 'hn', 'cn']) # the model's output names
# Out:
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\symbolic_opset9.py:4315: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with LSTM can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\_internal\jit_utils.py:258: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\utils.py:687: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# C:\Users\Brown Research\Anaconda3\envs\EyeTracking\lib\site-packages\torch\onnx\utils.py:1178: UserWarning: The shape inference of prim::Constant type is missing, so it may result in wrong shape inference for the exported graph. Please consider adding it in symbolic function. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\jit\passes\onnx\shape_type_inference.cpp:1888.)
#   _C._jit_pass_onnx_graph_shape_type_inference(

# %% [markdown]
# <b>Result<b>

# %%
X = X_series[:, 0:1, :]
y = y_series[:, 0, :]

print(X.shape, y.shape)
lr_xyz.to(device)
# Out:
# torch.Size([7195, 1, 9]) torch.Size([7195, 3])
# CustomLSTM(
#   (lstm): LSTM(9, 9, batch_first=True)
#   (fc): Sequential(
#     (0): Tanh()
#     (1): Linear(in_features=9, out_features=128, bias=True)
#     (2): Tanh()
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
train_predict, _, _ = lr_xyz(X.to(device))
data_predict = np.array([X[0, 0, 6:9].data.numpy()])
data_predict = np.append(data_predict, train_predict.data.cpu().numpy(), axis=0)

dataY_plot = np.array([X[0, 0, 6:9].data.numpy()])
dataY_plot = np.append(dataY_plot, y.data.numpy(), axis=0)
print(data_predict.shape, dataY_plot.shape)
# Out:
# (7196, 3) (7196, 3)

# %%
data_compound = [X[0, 0, 6:9].data.numpy()]
hn = None
cn = None
for i in range(X.size(0)):
    instance = X[i:i+1]
    pred, hn, cn = lr_xyz(instance.to(device), hn, cn)
    pred = nn.functional.normalize(pred)
    pred = pred.data.cpu().numpy()
    cur = X[i, 0, 6:9].data.numpy()
    data_compound.append(pred[0])
    if i < X.size(0) - 1:
        X[i+1,0,0:3] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,0:3] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,3:6] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,3:6] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,6] = pred[0,0].item()
        X[i+1,0,7] = pred[0,1].item()
        X[i+1,0,8] = pred[0,2].item()
data_compound = np.array(data_compound)
print(data_compound.shape)
# Out:
# (7196, 3)

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 0], label="Actual Data")
#plt.plot(data_predict[:, 0], label="Predicted Data")
plt.plot(data_compound[:, 0], label="Compounded Data")
plt.title("Neck Prediction X")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 1], label="Actual Data")
#plt.plot(data_predict[:, 1], label="Predicted Data")
plt.plot(data_compound[:, 1], label="Compounded Data")
plt.title("Neck Prediction Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.axvline(x=6000, c='r', linestyle="--")

plt.plot(dataY_plot[:, 2], label="Actual Data")
#plt.plot(data_predict[:, 2], label="Predicted Data")
plt.plot(data_compound[:, 2], label="Compounded Data")
plt.title("Neck Prediction Z")
plt.legend()
plt.show()

# %% [markdown]
# ## Testing on New Series

# %%
df = pd.read_csv("../EyeTrackingTest/Data/Test/2_1.txt", delimiter=",").iloc[:, :-1]

# %%
labelx = []
labely = []
labelz = []
for i in range(df.shape[0] - 1):
    label_row = df.iloc[i + 1]
    labelx.append(label_row["forward.x"])
    labely.append(label_row["forward.y"])
    labelz.append(label_row["forward.z"])
    
df = df.iloc[:-1, :]
df["label.x"] = labelx
df["label.y"] = labely
df["label.z"] = labelz
df.head(5)
# Out:
#           time(100ns)  time_stamp(ms)  frame  gaze_direct_L.x  \
# 0  638001315885795054          181877  10229         0.002441
# 1  638001315885875052          181885  10230         0.002487
# 2  638001315885955057          181893  10231         0.002533
# 3  638001315886045056          181902  10232         0.001099
# 4  638001315886125064          181910  10232         0.000565
#
#    gaze_direct_L.y  gaze_direct_L.z  gaze_direct_R.x  gaze_direct_R.y  \
# 0         0.089676         0.995956         0.026138         0.096710
# 1         0.090622         0.995880         0.026138         0.095886
# 2         0.090637         0.995865         0.026108         0.096298
# 3         0.088852         0.996033         0.025070         0.096069
# 4         0.089035         0.996018         0.024841         0.095840
#
#    gaze_direct_R.z  forward.x  forward.y  forward.z   label.x   label.y  \
# 0         0.994965   0.032196   0.070567   0.996987  0.032279  0.070550
# 1         0.995041   0.032279   0.070550   0.996986  0.032443  0.070451
# 2         0.994995   0.032443   0.070451   0.996988  0.032568  0.070438
# 3         0.995056   0.032568   0.070438   0.996984  0.032568  0.070438
# 4         0.995071   0.032568   0.070438   0.996984  0.032711  0.070426
#
#     label.z
# 0  0.996986
# 1  0.996988
# 2  0.996984
# 3  0.996984
# 4  0.996981

# %%
X = df.iloc[:, 3:-3].to_numpy()
y = df.iloc[:, -3:].to_numpy()

print(X.shape, y.shape)
# Out:
# (7200, 9) (7200, 3)

# %%
X = Variable(torch.Tensor(X))
y = Variable(torch.Tensor(y))

X = torch.reshape(X, (X.shape[0], 1, X.shape[1]))

# %%
train_predict, _, _ = lr_xyz(X.to(device))
data_predict = train_predict.data.cpu().numpy()
dataY_plot = y.data.numpy()

data_compound = [X[0, 0, 6:9].data.numpy()]
hn = None
cn = None
for i in range(X.size(0)):
    instance = X[i:i+1]
    pred, hn, cn = lr_xyz(instance.to(device), hn, cn)
    pred = pred.data.cpu().numpy()
    cur = X[i, 0, 6:9].data.numpy()
    data_compound.append(pred[0])
    if i < X.size(0) - 1:
        X[i+1,0,0:3] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,0:3] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,3:6] = nn.functional.normalize(torch.reshape(X[i+1,0,6:9] + X[i+1,0,3:6] - torch.Tensor(pred[0]), (1,3))).view(-1,3)
        X[i+1,0,6] = pred[0,0].item()
        X[i+1,0,7] = pred[0,1].item()
        X[i+1,0,8] = pred[0,2].item()
data_compound = np.array(data_compound)
print(data_compound.shape)

plt.figure(figsize=(10,6))

plt.plot(data)
plt.plot(dataY_plot[:, 0], label="Actual Data")
plt.plot(data_compound[:, 0], label="Predicted Data")
plt.title("Neck Prediction X")
plt.legend()
plt.show()
# Out:
# (7201, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 25
#      21 print(data_compound.shape)
#      23 plt.figure(figsize=(10,6))
# ---> 25 plt.plot(data)
#      26 plt.plot(dataY_plot[:, 0], label="Actual Data")
#      27 plt.plot(data_compound[:, 0], label="Predicted Data")
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(10,6))

plt.plot(dataY_plot[:, 1], label="Actual Data")
plt.plot(data_compound[:, 1], label="Predicted Data")
plt.title("Neck Prediction Y")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(dataY_plot[:, 2], label="Actual Data")
plt.plot(data_compound[:, 2], label="Predicted Data")
plt.title("Neck Prediction Z")
plt.legend()
plt.show()
